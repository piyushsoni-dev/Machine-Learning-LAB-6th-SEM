# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('mobilepurchase.csv')

# %%
data
# Out:
#      Brand PriceRange     Camera Battery  Buy
# 0  Premium       High  Excellent    Long  Yes
# 1  Premium       High       Good    Long  Yes
# 2      Mid     Medium       Good    Long  Yes
# 3   Budget        Low    Average   Short   No
# 4   Budget        Low       Poor   Short   No
# 5      Mid        Low    Average   Short   No

# %%
concepts = np.array(data)[:,:-1]

# %%
concepts
# Out:
# array([['Premium', 'High', 'Excellent', 'Long'],
#        ['Premium', 'High', 'Good', 'Long'],
#        ['Mid', 'Medium', 'Good', 'Long'],
#        ['Budget', 'Low', 'Average', 'Short'],
#        ['Budget', 'Low', 'Poor', 'Short'],
#        ['Mid', 'Low', 'Average', 'Short']], dtype=object)

# %%
target = np.array(data)[:,-1]

# %%
target
# Out:
# array(['Yes', 'Yes', 'Yes', 'No', 'No', 'No'], dtype=object)

# %%
def train(con, tar):
    for i, val in enumerate(tar):
        if val == 'Yes':
            specific_h = con[i].copy()
            break
            
    for i, val in enumerate(con):
        if tar[i] == 'Yes':
            for x in range(len(specific_h)):
                if val[x] != specific_h[x]:
                    specific_h[x] = '?'
                else:
                    pass
    return specific_h

# %%
print(train(concepts, target))
# Out:
# ['?' '?' '?' 'Long']
