# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib
# Out:
# Using matplotlib backend: module://matplotlib_inline.backend_inline

# %%
data=pd.read_csv("insurance.csv")

# %%
data
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test,y_train,y_test = train_test_split(data[['age']],data.bought_insurance,train_size=0.8)

# %%
x_test
# Out:
#     age
# 14   49
# 21   26
# 8    62
# 6    55
# 15   55
# 10   18

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
x_test
# Out:
#     age
# 14   49
# 21   26
# 8    62
# 6    55
# 15   55
# 10   18

# %%
y_predicted=model.predict(x_test)

# %%
model.predict_proba(x_test)
# Out:
# array([[0.12226709, 0.87773291],
#        [0.84094354, 0.15905646],
#        [0.01752424, 0.98247576],
#        [0.05118533, 0.94881467],
#        [0.05118533, 0.94881467],
#        [0.94931448, 0.05068552]])

# %%
model.score(x_test,y_test)
# Out:
# 0.8333333333333334

# %%
y_predicted
# Out:
# array([1, 0, 1, 1, 1, 0], dtype=int64)

# %%
x_test
# Out:
#     age
# 14   49
# 21   26
# 8    62
# 6    55
# 15   55
# 10   18
